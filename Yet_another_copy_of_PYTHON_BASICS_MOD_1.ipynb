# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhiydv17/1.-Call-Sentiment-Performance-Dashboard---product-sales-dashboard-/blob/main/Yet_another_copy_of_PYTHON_BASICS_MOD_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PYTHON INPUT OUTPUT

# %%
# Program to take input and print a message
name = input("Enter your name: ")
print("Hello,", name, "Welcome to Python Programming!")
# Out:
# Enter your name: rita
# Hello, rita Welcome to Python Programming!

# %%
# Program to add two numbers
num1 = 30   # first number
num2 = 20   # second number
sum = num1 + num2   # expression with operator +
print("The sum is:", sum)
# Out:
# The sum is: 50

# %%
# Integer, Float and String examples
age = 21           # int
height = 5.9       # float
student_name = "Rahul"  # string

print("Name:", student_name)
print("Age:", age)
print("Height:", height)
# Out:
# Name: Rahul
# Age: 21
# Height: 5.9

# %%
# Program to show escape sequences
print("Hello World")
print("Hello\nWorld")        # \n = new line
print("Hello\tWorld")        # \t = tab space
print("She said, \"Python is fun!\"")  # \" = double quote inside string
# Out:
# Hello World
# Hello
# World
# Hello	World
# She said, "Python is fun!"

# %%
# Program to show operator precedence
result = 3 + 5 * 2
print("3 + 5 * 2 =", result)   # Multiplication happens before addition

result2 = (3 + 5) * 2
print("(3 + 5) * 2 =", result2)  # Brackets change order
# Out:
# 3 + 5 * 2 = 13
# (3 + 5) * 2 = 16

# %%
# This is a single-line comment
# The following code prints a welcome message
print("Welcome to BCA Python class!")

"""
This is a multi-line comment
We can explain a program in detail here.
Python will ignore this.
"""
# Out:
# Welcome to BCA Python class!
# '\nThis is a multi-line comment\nWe can explain a program in detail here.\nPython will ignore this.\n'

# %%
# Application: Calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Addition:", num1 + num2)
print("Subtraction:", num1 - num2)
print("Multiplication:", num1 * num2)
print("Division:", num1 / num2)
# Out:
# Enter first number: 32
# Enter second number: 21
# Addition: 53.0
# Subtraction: 11.0
# Multiplication: 672.0
# Division: 1.5238095238095237

# %%
# Application: Convert Celsius to Fahrenheit
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print("Temperature in Fahrenheit:", fahrenheit)
# Out:
# Enter temperature in Celsius: 32
# Temperature in Fahrenheit: 89.6

# %%
# Application: Simple Interest Calculator
principal = float(input("Enter Principal amount: "))
rate = float(input("Enter Rate of interest (%): "))
time = float(input("Enter Time (in years): "))

simple_interest = (principal * rate * time) / 100
print("Simple Interest =", simple_interest)
# Out:
# Enter Principal amount: 234
# Enter Rate of interest (%): 7
# Enter Time (in years): 12
# Simple Interest = 196.56

# %%
# Application: Split a restaurant bill among friends
total_bill = float(input("Enter total bill amount: "))
friends = int(input("Enter number of friends: "))

share = total_bill / friends
print("Each friend has to pay:", share)
# Out:
# Enter total bill amount: 345
# Enter number of friends: 3
# Each friend has to pay: 115.0

# %%
# Application: Grade Calculator
marks = int(input("Enter marks out of 100: "))

if marks >= 90:
    grade = "A"
elif marks >= 75:
    grade = "B"
elif marks >= 50:
    grade = "C"
else:
    grade = "Fail"

print("Your Grade is:", grade)
# Out:
# Enter marks out of 100: 78
# Your Grade is: B
